# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data = sns.load_dataset('tips')#load data from seaborn

# %%
data.head()#show the first 5 rows of the data
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
data.tail()#show the last 5 rows of the data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
# pip install matplotlib

# %%
sns.lineplot(data['total_bill']) #plot the total bill column
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.scatterplot(x='total_bill', y='tip', data=data) #scatter plot
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.barplot(x='total_bill', y='tip', data=data) #default is mean
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.histplot(x='total_bill', y='tip', data=data)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.histplot(data['total_bill'])#histogram
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.kdeplot(data['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.relplot(x ='total_bill', y = 'tip', data=data)

# %%
data['time'].unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
sns.relplot(x='total_bill', y ='tip',hue='time',data=data)

# %%
sns.relplot(x='total_bill', y ='tip',hue='time',style='smoker',data=data)

# %%
data['smoker'].value_counts() # count the number of smokers and non-smokers
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
sns.barplot(data['smoker'])
# Out:
# <Axes: ylabel='smoker'>

# %%
sns.relplot(x='total_bill', y ='tip',hue='time',style='smoker',data=data,kind='scatter',col='smoker')

# %%
sns.relplot(x='total_bill', y ='tip',hue='time',style='smoker',data=data,kind='scatter',row='time')

# %%
data['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
sns.relplot(data['day'])

# %%
sns.relplot(x='total_bill',y='tip',hue='day',data=data,kind='line',col='day')

# %%
sns.relplot(x='total_bill',y='tip',hue='day',data=data,kind='scatter',col='day')

# %%
sns.relplot(x='total_bill',y='tip',data=data)
plt.title("total bill vs tip")
plt.xlabel('total_bill')
plt.ylabel('tip')
# Out:
# Text(13.819444444444445, 0.5, 'tip')
